# %%
def invKL(M):
    L = M.lattice_of_flats()
    if M.rank() == 0:
        return 1
    invKLpoly = sum((-1) ** M.delete(M.groundset()-L[i]).rank() * 
                    M.delete(M.groundset()-L[i]).lattice_of_flats().kazhdan_lusztig_polynomial() * 
                    invKL(M.contract(L[i])) 
                    for i in range(1, len(M.lattice_of_flats())))
    return -invKLpoly
    
def kl(M):
    return M.lattice_of_flats().kazhdan_lusztig_polynomial()

print([invKL(Matroid(graphs.CycleGraph(n))) for n in range(3, 11)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/misc/cachefunc.pyx:1962, in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:13399)()
#    1961 try:
# -> 1962     return cache[k]
#    1963 except TypeError:  # k is not hashable
#
# KeyError: (None, None)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 def kl(M):
#      12     return M.lattice_of_flats().kazhdan_lusztig_polynomial()
# ---> 14 print([invKL(Matroid(graphs.CycleGraph(n))) for n in range(Integer(3), Integer(11))])
#
# Cell In[4], line 14, in <listcomp>(.0)
#      11 def kl(M):
#      12     return M.lattice_of_flats().kazhdan_lusztig_polynomial()
# ---> 14 print([invKL(Matroid(graphs.CycleGraph(n))) for n in range(Integer(3), Integer(11))])
#
# Cell In[4], line 5, in invKL(M)
#       3 if M.rank() == Integer(0):
#       4     return Integer(1)
# ----> 5 invKLpoly = sum((-Integer(1)) ** M.delete(M.groundset()-L[i]).rank() *
#       6                 M.delete(M.groundset()-L[i]).lattice_of_flats().kazhdan_lusztig_polynomial() *
#       7                 invKL(M.contract(L[i]))
#       8                 for i in range(Integer(1), len(M.lattice_of_flats())))
#       9 return -invKLpoly
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/misc/functional.py:592, in symbolic_sum(expression, *args, **kwds)
#     590     return expression.sum(*args, **kwds)
#     591 if max(len(args), len(kwds)) <= 1:
# --> 592     return sum(expression, *args, **kwds)
#     593 from sage.symbolic.ring import SR
#     594 return SR(expression).sum(*args, **kwds)
#
# Cell In[4], line 7, in <genexpr>(.0)
#       3 if M.rank() == Integer(0):
#       4     return Integer(1)
#       5 invKLpoly = sum((-Integer(1)) ** M.delete(M.groundset()-L[i]).rank() *
#       6                 M.delete(M.groundset()-L[i]).lattice_of_flats().kazhdan_lusztig_polynomial() *
# ----> 7                 invKL(M.contract(L[i]))
#       8                 for i in range(Integer(1), len(M.lattice_of_flats())))
#       9 return -invKLpoly
#
# Cell In[4], line 5, in invKL(M)
#       3 if M.rank() == Integer(0):
#       4     return Integer(1)
# ----> 5 invKLpoly = sum((-Integer(1)) ** M.delete(M.groundset()-L[i]).rank() *
#       6                 M.delete(M.groundset()-L[i]).lattice_of_flats().kazhdan_lusztig_polynomial() *
#       7                 invKL(M.contract(L[i]))
#       8                 for i in range(Integer(1), len(M.lattice_of_flats())))
#       9 return -invKLpoly
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/misc/functional.py:592, in symbolic_sum(expression, *args, **kwds)
#     590     return expression.sum(*args, **kwds)
#     591 if max(len(args), len(kwds)) <= 1:
# --> 592     return sum(expression, *args, **kwds)
#     593 from sage.symbolic.ring import SR
#     594 return SR(expression).sum(*args, **kwds)
#
# Cell In[4], line 7, in <genexpr>(.0)
#       3 if M.rank() == Integer(0):
#       4     return Integer(1)
#       5 invKLpoly = sum((-Integer(1)) ** M.delete(M.groundset()-L[i]).rank() *
#       6                 M.delete(M.groundset()-L[i]).lattice_of_flats().kazhdan_lusztig_polynomial() *
# ----> 7                 invKL(M.contract(L[i]))
#       8                 for i in range(Integer(1), len(M.lattice_of_flats())))
#       9 return -invKLpoly
#
# Cell In[4], line 5, in invKL(M)
#       3 if M.rank() == Integer(0):
#       4     return Integer(1)
# ----> 5 invKLpoly = sum((-Integer(1)) ** M.delete(M.groundset()-L[i]).rank() *
#       6                 M.delete(M.groundset()-L[i]).lattice_of_flats().kazhdan_lusztig_polynomial() *
#       7                 invKL(M.contract(L[i]))
#       8                 for i in range(Integer(1), len(M.lattice_of_flats())))
#       9 return -invKLpoly
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/misc/functional.py:592, in symbolic_sum(expression, *args, **kwds)
#     590     return expression.sum(*args, **kwds)
#     591 if max(len(args), len(kwds)) <= 1:
# --> 592     return sum(expression, *args, **kwds)
#     593 from sage.symbolic.ring import SR
#     594 return SR(expression).sum(*args, **kwds)
#
# Cell In[4], line 6, in <genexpr>(.0)
#       3 if M.rank() == Integer(0):
#       4     return Integer(1)
#       5 invKLpoly = sum((-Integer(1)) ** M.delete(M.groundset()-L[i]).rank() *
# ----> 6                 M.delete(M.groundset()-L[i]).lattice_of_flats().kazhdan_lusztig_polynomial() *
#       7                 invKL(M.contract(L[i]))
#       8                 for i in range(Integer(1), len(M.lattice_of_flats())))
#       9 return -invKLpoly
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/combinat/posets/posets.py:8786, in FinitePoset.kazhdan_lusztig_polynomial(self, x, y, q, canonical_labels)
#    8784 if q is None:
#    8785     q = PolynomialRing(ZZ, 'q').gen(0)
# -> 8786 poly = self._kl_poly(x, y, canonical_labels)
#    8787 return poly(q=q)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/misc/cachefunc.pyx:1967, in sage.misc.cachefunc.CachedMethodCaller.__call__ (build/cythonized/sage/misc/cachefunc.c:13535)()
#    1965         return cache[k]
#    1966 except KeyError:
# -> 1967     w = self._instance_call(*args, **kwds)
#    1968     cache[k] = w
#    1969     return w
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/misc/cachefunc.pyx:1842, in sage.misc.cachefunc.CachedMethodCaller._instance_call (build/cythonized/sage/misc/cachefunc.c:12984)()
#    1840         True
#    1841     """
# -> 1842     return self.f(self._instance, *args, **kwds)
#    1843
#    1844 cdef fix_args_kwds(self, tuple args, dict kwds) noexcept:
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/combinat/posets/posets.py:8714, in FinitePoset._kl_poly(self, x, y, canonical_labels)
#    8712     def sublat(P):
#    8713         return self.subposet(P)
# -> 8714 poly = -sum(sublat(self.order_ideal([x])).characteristic_polynomial() *
#    8715             sublat(self.order_filter([x])).kazhdan_lusztig_polynomial()
#    8716             for x in self if x != min_elt)
#    8717 tr = self.rank() // 2 + 1
#    8718 ret = poly.truncate(tr)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/combinat/posets/posets.py:8714, in <genexpr>(.0)
#    8712     def sublat(P):
#    8713         return self.subposet(P)
# -> 8714 poly = -sum(sublat(self.order_ideal([x])).characteristic_polynomial() *
#    8715             sublat(self.order_filter([x])).kazhdan_lusztig_polynomial()
#    8716             for x in self if x != min_elt)
#    8717 tr = self.rank() // 2 + 1
#    8718 ret = poly.truncate(tr)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/combinat/posets/posets.py:8710, in FinitePoset._kl_poly.<locals>.sublat(P)
#    8709 def sublat(P):
# -> 8710     return self.subposet(P).canonical_label()
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/combinat/posets/posets.py:6421, in FinitePoset.subposet(self, elements)
#    6419 else:
#    6420     g.relabel(lambda v: self._vertex_to_element(v).element, inplace=True)
# -> 6421 return Poset(g, cover_relations=False, facade=self._is_facade)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/combinat/posets/posets.py:749, in Poset(data, element_labels, cover_relations, linear_extension, category, facade, key)
#     747 if not cover_relations:
#     748     from sage.graphs.generic_graph_pyx import transitive_reduction_acyclic
# --> 749     D = transitive_reduction_acyclic(D)
#     751 # Check that the digraph does not contain loops, multiple edges
#     752 # and is transitively reduced.
#     753 if D.has_loops():
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/graphs/generic_graph_pyx.pyx:1605, in sage.graphs.generic_graph_pyx.transitive_reduction_acyclic (build/cythonized/sage/graphs/generic_graph_pyx.c:29048)()
#    1603 for uu in linear_extension:
#    1604     u = v_to_int[uu]
# -> 1605     for vv in G.neighbors_out(uu):
#    1606         v = v_to_int[vv]
#    1607         binary_matrix_set1(closure, u, v)
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/graphs/digraph.py:1251, in DiGraph.neighbors_out(self, vertex)
#    1239 def neighbors_out(self, vertex):
#    1240     """
#    1241     Return the list of the out-neighbors of a given vertex.
#    1242
#    (...)
#    1249         [1, 2, 3]
#    1250     """
# -> 1251     return list(self.neighbor_out_iterator(vertex))
#
# File /private/var/tmp/sage-10.3-current/local/var/lib/sage/venv-python3.11.8/lib/python3.11/site-packages/sage/graphs/digraph.py:1237, in DiGraph.neighbor_out_iterator(self, vertex)
#    1222 def neighbor_out_iterator(self, vertex):
#    1223     """
#    1224     Return an iterator over the out-neighbors of a given vertex.
#    1225
#    (...)
#    1235         3
#    1236     """
# -> 1237     return iter(set(self._backend.iterator_out_nbrs(vertex)))
#
# File src/cysignals/signals.pyx:341, in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
n = 4
B = matroids.Uniform(3,5)
L = B.lattice_of_flats()
frozenChains = list(L.chains())
maxChains = [[list(chain) for chain in p][1:] for p in frozenChains if len(p) == B.rank() + 1]
for x in maxChains:
    print(x)
L.show()
# Out:
# [[2], [2, 3], [0, 1, 2, 3, 4]]
# [[2], [1, 2], [0, 1, 2, 3, 4]]
# [[2], [2, 4], [0, 1, 2, 3, 4]]
# [[2], [0, 2], [0, 1, 2, 3, 4]]
# [[3], [2, 3], [0, 1, 2, 3, 4]]
# [[3], [1, 3], [0, 1, 2, 3, 4]]
# [[3], [3, 4], [0, 1, 2, 3, 4]]
# [[3], [0, 3], [0, 1, 2, 3, 4]]
# [[1], [1, 2], [0, 1, 2, 3, 4]]
# [[1], [1, 3], [0, 1, 2, 3, 4]]
# [[1], [1, 4], [0, 1, 2, 3, 4]]
# [[1], [0, 1], [0, 1, 2, 3, 4]]
# [[4], [1, 4], [0, 1, 2, 3, 4]]
# [[4], [2, 4], [0, 1, 2, 3, 4]]
# [[4], [3, 4], [0, 1, 2, 3, 4]]
# [[4], [0, 4], [0, 1, 2, 3, 4]]
# [[0], [0, 3], [0, 1, 2, 3, 4]]
# [[0], [0, 1], [0, 1, 2, 3, 4]]
# [[0], [0, 2], [0, 1, 2, 3, 4]]
# [[0], [0, 4], [0, 1, 2, 3, 4]]
# Graphics object consisting of 53 graphics primitives
